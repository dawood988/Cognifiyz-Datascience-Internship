# %% [markdown]
# # Cognifiyz  Data Science Internship

# %% [markdown]
# # Level - 1

# %% [markdown]
# # Task 1: Data Exploration and Preprocessing

# %%
import pandas as pd
import numpy as np

# %%
file =  r"C:\Users\Dawood MD\OneDrive\Desktop\Cognifyz\Dataset .csv"

# %%
import chardet
with open (file , 'rb') as rawdata:
    result = chardet.detect(rawdata.read(1000000))
result
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
df = pd.read_csv(file,encoding='latin-1',encoding_errors='replace')

# %%
df.head()
# Out:
#    ï»¿Restaurant ID         Restaurant Name  Country Code              City  \
# 0           6317637        Le Petit Souffle           162       Makati City
# 1           6304287        Izakaya Kikufuji           162       Makati City
# 2           6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                    Ooma           162  Mandaluyong City
# 4           6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code           City  \
# 9546        5915730              NamlÛ± Gurme           208  ï¿½ï¿½stanbul
# 9547        5908749         Ceviz Aï¿½ï¿½acÛ±           208  ï¿½ï¿½stanbul
# 9548        5915807                     Huqqa           208  ï¿½ï¿½stanbul
# 9549        5916112         Aï¿½ï¿½ï¿½k Kahve           208  ï¿½ï¿½stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ï¿½ï¿½stanbul
#
#                                                 Address           Locality  \
# 9546  Kemankeï¿½ï¿½ Karamustafa Paï¿½ï¿½a Mahallesi,...         Karakï¿½_y
# 9547  Koï¿½ï¿½uyolu Mahallesi, Muhittin ï¿½ï¿½stï¿½_...      Koï¿½ï¿½uyolu
# 9548  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...  Kuruï¿½_eï¿½ï¿½me
# 9549  Kuruï¿½_eï¿½ï¿½me Mahallesi, Muallim Naci Cadd...  Kuruï¿½_eï¿½ï¿½me
# 9550  Cafeaï¿½ï¿½a Mahallesi, BademaltÛ± Sokak, No 2...               Moda
#
#                       Locality Verbose  Longitude   Latitude  \
# 9546         Karakï¿½_y, ï¿½ï¿½stanbul  28.977392  41.022793
# 9547      Koï¿½ï¿½uyolu, ï¿½ï¿½stanbul  29.041297  41.009847
# 9548  Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul  29.034640  41.055817
# 9549  Kuruï¿½_eï¿½ï¿½me, ï¿½ï¿½stanbul  29.036019  41.057979
# 9550               Moda, ï¿½ï¿½stanbul  29.026016  40.984776
#
#                              Cuisines  ...          Currency  \
# 9546                          Turkish  ...  Turkish Lira(TL)
# 9547  World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548           Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549                  Restaurant Cafe  ...  Turkish Lira(TL)
# 9550                             Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [5 rows x 21 columns]

# %%
df.rename(columns={'ï»¿Restaurant ID' : 'Restaurant ID'},inplace=True)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...          Currency Has Table booking  \
# 0        French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                          Japanese  ...  Botswana Pula(P)               Yes
# 2  Seafood, Asian, Filipino, Indian  ...  Botswana Pula(P)               Yes
# 3                   Japanese, Sushi  ...  Botswana Pula(P)                No
# 4                  Japanese, Korean  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
# 2               4.4         Green   Very Good   270
# 3               4.9    Dark Green   Excellent   365
# 4               4.8    Dark Green   Excellent   229
#
# [5 rows x 21 columns]

# %% [markdown]
# Explore the dataset and identify the number of rows and columns.

# %%
print('Number fo rows and columns:',df.shape)
# Out:
# Number fo rows and columns: (9551, 21)

# %% [markdown]
# Correction of the corrupted words from the dataset

# %%
# Define a function to replace special characters
def replace_special_characters(text):
    special_char_replacements = {
        'ï¿½': 'i',
        'Û': 'u',
        '±': 'i',
        'Ä': 'A',
        'ç': 'c',
        'Ç': 'C',
        'Ü': 'U',
        'Ö': 'O',
        'Ş': 'S',
        'Ğ': 'G',
        'İ': 'I',
        'ş': 's',
        'ü': 'u',
        'ö': 'o',
        'ğ': 'g',
        'İ': 'I',
        'â': 'a'
    }
    for key, value in special_char_replacements.items():
        text = text.replace(key, value)
    return text

# %%
# Apply the function to relevant columns
columns_to_replace = ['Restaurant Name','City','Address','Locality','Locality Verbose']

# %%
for column in columns_to_replace:
    df[column] = df[column].apply(replace_special_characters)

# %%
df.head(25)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# 12        6318433                          Silantro Fil-Mex           162
# 13        6310470                                Guevarra's           162
# 14        6314605                   Sodam Korean Restaurant           162
# 15       18185059                             Cafe Arabelle           162
# 16       18182702                  Nonna's Pasta & Pizzeria           162
# 17        6318213                                Balay Dako           162
# 18       18255654                Hobing Korean Dessert Cafe           162
# 19        6308205                   Wildflour Cafe + Bakery           162
# 20        6315438                            NIU by Vikings           162
# 21        6310406             The Food Hall by Todd English           162
# 22        6600681                               Chez Michou            30
# 23        6601005                       Cafii Daniel Briand            30
# 24        6600292                  Casa do Biscoito Mineiro            30
#
#                 City                                            Address  \
# 0        Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1        Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2   Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3   Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4   Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
# 5   Mandaluyong City  Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 6         Pasay City  Building K, SM By The Bay, Sunset Boulevard, M...
# 7         Pasay City  Building B, By The Bay, Seaside Boulevard, Mal...
# 8         Pasay City  Plaza Level, Sofitel Philippine Plaza Manila, ...
# 9         Pasig City  Brixton Technology Center, 10 Brixton Street, ...
# 10        Pasig City       75 East Capitol Drive, Kapitolyo, Pasig City
# 11        Pasig City       23 East Capitol Drive, Kapitolyo, Pasig City
# 12       Quezon City  Second Floor, UP Town Center, Katipunan Avenue...
# 13     San Juan City  387 P. Guevarra Corner Argonne Street, Additio...
# 14     San Juan City  17 J. Abad Santos Drive, Little Baguio, San Ju...
# 15        Santa Rosa  Ayala Mall, Solenad, Nuvali, Santa Rosa - Taga...
# 16        Santa Rosa  Ground Floor, Building G, Solenad 3, Nuvali, D...
# 17     Tagaytay City                   Aguinaldo Highway, Tagaytay City
# 18       Taguig City  Third Floor, BGC Stopover Pavillion, Rizal Dri...
# 19       Taguig City  Ground Floor, Netlima Building, 4th Avenue Cor...
# 20       Taguig City  Sixth Floor, SM Aura Premier, C5 Road Corner 2...
# 21       Taguig City  Fifth Floor, SM Aura Premier, C5 Corner 26th S...
# 22         Brasi_lia  SCLN, 208, Bloco A, Loja 30, Asa Norte, Brasi_lia
# 23         Brasi_lia   SCLN 104, Bloco A, Loja 26, Asa Norte, Brasi_lia
# 24         Brasi_lia  SCLN 210, Bloco D, Loja 36/48, Asa Norte, Bras...
#
#                                              Locality  \
# 0           Century City Mall, Poblacion, Makati City
# 1          Little Tokyo, Legaspi Village, Makati City
# 2          Edsa Shangri-La, Ortigas, Mandaluyong City
# 3              SM Megamall, Ortigas, Mandaluyong City
# 4              SM Megamall, Ortigas, Mandaluyong City
# 5              SM Megamall, Ortigas, Mandaluyong City
# 6     SM by the Bay, Mall of Asia Complex, Pasay City
# 7     SM by the Bay, Mall of Asia Complex, Pasay City
# 8         Sofitel Philippine Plaza Manila, Pasay City
# 9                                           Kapitolyo
# 10                                          Kapitolyo
# 11                                          Kapitolyo
# 12               UP Town Center, Diliman, Quezon City
# 13                                     Addition Hills
# 14                                      Little Baguio
# 15                       Nuvali, Don Jose, Santa Rosa
# 16                    Solenad 3, Don Jose, Santa Rosa
# 17                                      Tagaytay City
# 18      BGC Stopover Pavillion, Bonifacio Global City
# 19                              Bonifacio Global City
# 20  SM Aura Premier, Bonifacio Global City, Taguig...
# 21  SM Aura Premier, Bonifacio Global City, Taguig...
# 22                                          Asa Norte
# 23                                          Asa Norte
# 24                                          Asa Norte
#
#                                      Locality Verbose   Longitude   Latitude  \
# 0   Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1   Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2   Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3   SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4   SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
# 5   SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056314  14.583764
# 6   SM by the Bay, Mall of Asia Complex, Pasay Cit...  120.979667  14.531333
# 7   SM by the Bay, Mall of Asia Complex, Pasay Cit...  120.979333  14.540000
# 8   Sofitel Philippine Plaza Manila, Pasay City, P...  120.980090  14.552990
# 9                               Kapitolyo, Pasig City  121.056532  14.572041
# 10                              Kapitolyo, Pasig City  121.057916  14.567689
# 11                              Kapitolyo, Pasig City  121.060820  14.570849
# 12  UP Town Center, Diliman, Quezon City, Quezon City  121.075419  14.649503
# 13                      Addition Hills, San Juan City  121.033592  14.593450
# 14                       Little Baguio, San Juan City  121.038110  14.598890
# 15           Nuvali, Don Jose, Santa Rosa, Santa Rosa  121.057040  14.237082
# 16        Solenad 3, Don Jose, Santa Rosa, Santa Rosa  121.056587  14.237679
# 17                       Tagaytay City, Tagaytay City  120.951589  14.101834
# 18  BGC Stopover Pavillion, Bonifacio Global City,...  121.045878  14.554360
# 19                 Bonifacio Global City, Taguig City  121.046220  14.549337
# 20  SM Aura Premier, Bonifacio Global City, Taguig...  121.053725  14.545858
# 21  SM Aura Premier, Bonifacio Global City, Taguig...  121.053500  14.545655
# 22                               Asa Norte, Brasi_lia  -47.881789 -15.764142
# 23                               Asa Norte, Brasi_lia  -47.882667 -15.777500
# 24                               Asa Norte, Brasi_lia  -47.882136 -15.757472
#
#                                       Cuisines  ...            Currency  \
# 0                   French, Japanese, Desserts  ...    Botswana Pula(P)
# 1                                     Japanese  ...    Botswana Pula(P)
# 2             Seafood, Asian, Filipino, Indian  ...    Botswana Pula(P)
# 3                              Japanese, Sushi  ...    Botswana Pula(P)
# 4                             Japanese, Korean  ...    Botswana Pula(P)
# 5                                      Chinese  ...    Botswana Pula(P)
# 6                              Asian, European  ...    Botswana Pula(P)
# 7           Seafood, Filipino, Asian, European  ...    Botswana Pula(P)
# 8                      European, Asian, Indian  ...    Botswana Pula(P)
# 9                                     Filipino  ...    Botswana Pula(P)
# 10                           Filipino, Mexican  ...    Botswana Pula(P)
# 11               American, Ice Cream, Desserts  ...    Botswana Pula(P)
# 12                           Filipino, Mexican  ...    Botswana Pula(P)
# 13                                    Filipino  ...    Botswana Pula(P)
# 14                                      Korean  ...    Botswana Pula(P)
# 15           Cafe, American, Italian, Filipino  ...    Botswana Pula(P)
# 16                              Italian, Pizza  ...    Botswana Pula(P)
# 17                                    Filipino  ...    Botswana Pula(P)
# 18                      Cafe, Korean, Desserts  ...    Botswana Pula(P)
# 19             Cafe, Bakery, American, Italian  ...    Botswana Pula(P)
# 20  Seafood, American, Mediterranean, Japanese  ...    Botswana Pula(P)
# 21           American, Asian, Italian, Seafood  ...    Botswana Pula(P)
# 22                           Fast Food, French  ...  Brazilian Real(R$)
# 23                                        Cafe  ...  Brazilian Real(R$)
# 24                                      Bakery  ...  Brazilian Real(R$)
#
#    Has Table booking Has Online delivery Is delivering now  \
# 0                Yes                  No                No
# 1                Yes                  No                No
# 2                Yes                  No                No
# 3                 No                  No                No
# 4                Yes                  No                No
# 5                 No                  No                No
# 6                Yes                  No                No
# 7                Yes                  No                No
# 8                Yes                  No                No
# 9                Yes                  No                No
# 10                No                  No                No
# 11               Yes                  No                No
# 12                No                  No                No
# 13               Yes                  No                No
# 14                No                  No                No
# 15                No                  No                No
# 16                No                  No                No
# 17               Yes                  No                No
# 18                No                  No                No
# 19               Yes                  No                No
# 20               Yes                  No                No
# 21               Yes                  No                No
# 22                No                  No                No
# 23                No                  No                No
# 24                No                  No                No
#
#    Switch to order menu Price range  Aggregate rating  Rating color  \
# 0                    No           3               4.8    Dark Green
# 1                    No           3               4.5    Dark Green
# 2                    No           4               4.4         Green
# 3                    No           4               4.9    Dark Green
# 4                    No           4               4.8    Dark Green
# 5                    No           3               4.4         Green
# 6                    No           4               4.0         Green
# 7                    No           4               4.2         Green
# 8                    No           4               4.9    Dark Green
# 9                    No           3               4.8    Dark Green
# 10                   No           3               4.9    Dark Green
# 11                   No           3               4.2         Green
# 12                   No           3               4.8    Dark Green
# 13                   No           3               4.2         Green
# 14                   No           3               4.3         Green
# 15                   No           3               3.6        Yellow
# 16                   No           3               4.0         Green
# 17                   No           3               4.5    Dark Green
# 18                   No           2               4.5    Dark Green
# 19                   No           4               4.4         Green
# 20                   No           4               4.7    Dark Green
# 21                   No           4               4.5    Dark Green
# 22                   No           2               3.0        Orange
# 23                   No           1               3.8        Yellow
# 24                   No           2               3.7        Yellow
#
#    Rating text Votes
# 0    Excellent   314
# 1    Excellent   591
# 2    Very Good   270
# 3    Excellent   365
# 4    Excellent   229
# 5    Very Good   336
# 6    Very Good   520
# 7    Very Good   677
# 8    Excellent   621
# 9    Excellent   532
# 10   Excellent  1070
# 11   Very Good   488
# 12   Excellent   294
# 13   Very Good   458
# 14   Very Good   223
# 15        Good    29
# 16   Very Good    72
# 17   Excellent   211
# 18   Excellent   118
# 19   Very Good   392
# 20   Excellent   535
# 21   Excellent   618
# 22     Average     6
# 23        Good     9
# 24        Good    11
#
# [25 rows x 21 columns]

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              Namlui Gurme           208  iistanbul
# 9547        5908749             Ceviz Aiiacui           208  iistanbul
# 9548        5915807                     Huqqa           208  iistanbul
# 9549        5916112               Aiiik Kahve           208  iistanbul
# 9550        5927402  Walter's Coffee Roastery           208  iistanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeii Karamustafa Paiia Mahallesi, Ruihtui...     Karaki_y
# 9547  Koiiuyolu Mahallesi, Muhittin iisti_ndaii Cadd...    Koiiuyolu
# 9548  Kurui_eiime Mahallesi, Muallim Naci Caddesi, N...  Kurui_eiime
# 9549  Kurui_eiime Mahallesi, Muallim Naci Caddesi, N...  Kurui_eiime
# 9550  Cafeaiia Mahallesi, Bademaltui Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karaki_y, iistanbul  28.977392  41.022793
# 9547    Koiiuyolu, iistanbul  29.041297  41.009847
# 9548  Kurui_eiime, iistanbul  29.034640  41.055817
# 9549  Kurui_eiime, iistanbul  29.036019  41.057979
# 9550         Moda, iistanbul  29.026016  40.984776
#
#                              Cuisines  ...          Currency  \
# 9546                          Turkish  ...  Turkish Lira(TL)
# 9547  World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9548           Italian, World Cuisine  ...  Turkish Lira(TL)
# 9549                  Restaurant Cafe  ...  Turkish Lira(TL)
# 9550                             Cafe  ...  Turkish Lira(TL)
#
#      Has Table booking Has Online delivery Is delivering now  \
# 9546                No                  No                No
# 9547                No                  No                No
# 9548                No                  No                No
# 9549                No                  No                No
# 9550                No                  No                No
#
#      Switch to order menu Price range  Aggregate rating  Rating color  \
# 9546                   No           3               4.1         Green
# 9547                   No           3               4.2         Green
# 9548                   No           4               3.7        Yellow
# 9549                   No           4               4.0         Green
# 9550                   No           2               4.0         Green
#
#      Rating text Votes
# 9546   Very Good   788
# 9547   Very Good  1034
# 9548        Good   661
# 9549   Very Good   901
# 9550   Very Good   591
#
# [5 rows x 21 columns]

# %% [markdown]
# Data Information , Description and Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
#  15  Switch to order menu  9551 non-null   object
#  16  Price range           9551 non-null   int64
#  17  Aggregate rating      9551 non-null   float64
#  18  Rating color          9551 non-null   object
#  19  Rating text           9551 non-null   object
#  20  Votes                 9551 non-null   int64
# dtypes: float64(3), int64(5), object(13)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    131.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# Check for missing values in each column and
#  handle them accordingly.

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
from unidecode import unidecode


# Function to apply unidecode to each text entry
def fix_encoding_issues(text):
    return unidecode(text)

# Apply the function to all string columns in the DataFrame
for column in df.select_dtypes(include=[object]).columns:
    df[column] = df[column].apply(lambda x: fix_encoding_issues(str(x)))

# Display the corrected DataFrame
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              Namlui Gurme           208  iistanbul
# 9547        5908749             Ceviz Aiiacui           208  iistanbul
# 9548        5915807                     Huqqa           208  iistanbul
# 9549        5916112               Aiiik Kahve           208  iistanbul
# 9550        5927402  Walter's Coffee Roastery           208  iistanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeii Karamustafa Paiia Mahallesi, Ruihtui...     Karaki_y
# 9547  Koiiuyolu Mahallesi, Muhittin iisti_ndaii Cadd...    Koiiuyolu
# 9548  Kurui_eiime Mahallesi, Muallim Naci Caddesi, N...  Kurui_eiime
# 9549  Kurui_eiime Mahallesi, Muallim Naci Caddesi, N...  Kurui_eiime
# 9550  Cafeaiia Mahallesi, Bademaltui Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karaki_y, iistanbul  28.977392  41.022793
# 9547    Koiiuyolu, iistanbul  29.041297  41.009847
# 9548  Kurui_eiime, iistanbul  29.034640  41.055817
# 9549  Kurui_eiime, iistanbul  29.036019  41.057979
# 9550         Moda, iistanbul  29.026016  40.984776
#
#                              Cuisines  ...          Currency  \
# 9546                          Turkish  ...  Turkish Lira(TL)
# 9547  World Cuisine, Patisserie, Cafe  ...  Turkish Lira(TL)
# 9

#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 4298                  No                No                   No           4
# 2872                  No                No                   No           1
# 2206                  No                No                   No           1
# 8819                  No                No                   No           2
# 1463                 Yes                No                   No           3
# 5287                  No                No                   No           1
# 6348                  No                No                   No           1
# 6205                  No                No                   No           1
# 5335                  No                No                   No           1
# 9512                  No                No                   No           4
#
#       Aggregate rating  Rating color Rating text Votes
# 4298               4.9    Dark Green   Excellent   408
# 2872               3.8        Yellow        Good    59
# 2206               0.0         White   Not rated     0
# 8819               3.0        Orange     Average     7
# 1463               2.8        Orange     Average   261
# 5287               0.0         White   Not rated     0
# 6348               3.2        Orange     Average    18
# 6205               2.8        Orange     Average    29
# 5335               3.8        Yellow        Good    94
# 9512               4.0         Green   Very Good   196
#
# [10 rows x 21 columns]

# %% [markdown]
# Perform data type conversion if necessary.

# %%
# Defining the Dictinary for the Rating and convert it to float values
rating_mapping = {'Excellent' : 5 , 'Very Good' : 4 , 'Good' : 3 , 'Average' : 2 , 'Bad' : 1 , 'Not rated': 0 }

# Applying the custom transformation using lambda function
df['Numeric rating'] = df["Rating text"].apply(lambda x :rating_mapping.get(x))

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# 3      SM Megamall, Ortigas, Mandaluyong City
# 4      SM Megamall, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831  14.581404
# 3  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475  14.585318
# 4  SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508  14.584450
#
#                            Cuisines  ...  Has Table booking  \
# 0        French, Japanese, Desserts  ...                Yes
# 1                          Japanese  ...                Yes
# 2  Seafood, Asian, Filipino, Indian  ...                Yes
# 3                   Japanese, Sushi  ...                 No
# 4                  Japanese, Korean  ...                Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
# 2                  No                No                   No           4
# 3                  No                No                   No           4
# 4                  No                No                   No           4
#
#   Aggregate rating  Rating color  Rating text Votes Numeric rating
# 0              4.8    Dark Green    Excellent   314            5.0
# 1              4.5    Dark Green    Excellent   591            5.0
# 2              4.4         Green    Very Good   270            4.0
# 3              4.9    Dark Green    Excellent   365            5.0
# 4              4.8    Dark Green    Excellent   229            5.0
#
# [5 rows x 22 columns]

# %% [markdown]
# Analyze the distribution of the target variable ("Aggregate rating") and identify any class imbalances.

# %%
print(df['Aggregate rating'].value_counts())
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     495
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     399
# 2.9     381
# 3.9     332
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     143
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      41
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df['Aggregate rating'],bins=[0, 1, 2, 3, 4, 5])
plt.xlabel('Aggregate rating')
plt.ylabel('Number of ratings')
plt.title('Aggregate rating vs. Number of ratings')
# Out:
# Text(0.5, 1.0, 'Aggregate rating vs. Number of ratings')

# %%
print(df['Rating text'].value_counts())
# Out:
# Average      3734
# Not rated    2148
# Good         2096
# Very Good    1078
# Excellent     300
# Poor          186
# Name: Rating text, dtype: int64

# %% [markdown]
# From the above outputs we can see that there are 2148 of not rated i,e. Aggregate rating is 0.0 .
#
# If we wanna to analyze it we have to ignore the 0.0 or not rated data from the datset .

# %%
df_clean = df[df['Aggregate rating']!= 0.0]

# %%
df_clean
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              Namlui Gurme           208         iistanbul
# 9547        5908749             Ceviz Aiiacui           208         iistanbul
# 9548        5915807                     Huqqa           208         iistanbul
# 9549        5916112               Aiiik Kahve           208         iistanbul
# 9550        5927402  Walter's Coffee Roastery           208         iistanbul
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# 9546  Kemankeii Karamustafa Paiia Mahallesi, Ruihtui...
# 9547  Koiiuyolu Mahallesi, Muhittin iisti_ndaii Cadd...
# 9548  Kurui_eiime Mahallesi, Muallim Naci Caddesi, N...
# 9549  Kurui_eiime Mahallesi, Muallim Naci Caddesi, N...
# 9550  Cafeaiia Mahallesi, Bademaltui Sokak, No 21/B,...
#
#                                         Locality  \
# 0      Century City Mall, Poblacion, Makati City
# 1     Little Tokyo, Legaspi Village, Makati City
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City
# 3         SM Megamall, Ortigas, Mandaluyong City
# 4         SM Megamall, Ortigas, Mandaluyong City
# ...                                          ...
# 9546                                    Karaki_y
# 9547                                   Koiiuyolu
# 9548                                 Kurui_eiime
# 9549                                 Kurui_eiime
# 9550                                        Moda
#
#                                        Locality Verbose   Longitude  \
# 0     Century City Mall, Poblacion, Makati City, Mak...  121.027535
# 1     Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101
# 2     Edsa Shangri-La, Ortigas, Mandaluyong City, Ma...  121.056831
# 3     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.056475
# 4     SM Megamall, Ortigas, Mandaluyong City, Mandal...  121.057508
# ...                                                 ...         ...
# 9546                                Karaki_y, iistanbul   28.977392
# 9547                               Koiiuyolu, iistanbul   29.041297
# 9548                             Kurui_eiime, iistanbul   29.034640
# 9549                             Kurui_eiime, iistanbul   29.036019
# 9550                                    Moda, iistanbul   29.026016
#
#        Latitude                          Cuisines  ...  Has Table booking  \
# 0     14.565443        French, Japanese, Desserts  ...                Yes
# 1     14.553708                          Japanese  ...                Yes
# 2     14.581404  Seafood, Asian, Filipino, Indian  ...                Yes
# 3     14.585318                   Japanese, Sushi  ...                 No
# 4     14.584450                  Japanese, Korean  ...                Yes
# ...         ...                               ...  ...                ...
# 9546  41.022793                           Turkish  ...                 No
# 9547  41.009847   World Cuisine, Patisserie, Cafe  ...                 No
# 9548  41.055817            Italian, World Cuisine  ...                 No
# 9549  41.057979                   Restaurant Cafe  ...                 No
# 9550  40.984776                              Cafe  ...                 No
#
#      Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                     No                No                   No           3
# 1                     No                No                   No           3
# 2                     No                No                   No           4
# 3                     No                No                   No           4
# 4                     No                No                   No           4
# ...                  ...               ...                  ...         ...
# 9546                  No                No                   No           3
# 9547                  No                No                   No           3
# 9548                  No                No                   No           4
# 9549                  No                No                   No           4
# 9550                  No                No                   No           2
#
#      Aggregate rating  Rating color  Rating text Votes Numeric rating
# 0                 4.8    Dark Green    Excellent   314            5.0
# 1                 4.5    Dark Green    Excellent   591            5.0
# 2                 4.4         Green    Very Good   270            4.0
# 3                 4.9    Dark Green    Excellent   365            5.0
# 4                 4.8    Dark Green    Excellent   229            5.0
# ...               ...           ...          ...   ...            ...
# 9546              4.1         Green    Very Good   788            4.0
# 9547              4.2         Green    Very Good  1034            4.0
# 9548              3.7        Yellow         Good   661            3.0
# 9549              4.0         Green    Very Good   901            4.0
# 9550              4.0         Green    Very Good   591            4.0
#
# [7394 rows x 22 columns]

# %%
# Evaluating the cleaned and before cleaned datset 
print("Number of rows and columns in df before cleaning",df.shape)

print("Number of rows and columns in df after cleaning",df_clean.shape)
# Out:
# Number of rows and columns in df before cleaning (9542, 26)
# Number of rows and columns in df after cleaning (7394, 22)

# %%
print(df_clean["Aggregate rating"].value_counts())
# Out:
# 3.2    522
# 3.1    519
# 3.4    495
# 3.3    483
# 3.5    480
# 3.0    468
# 3.6    458
# 3.7    427
# 3.8    399
# 2.9    381
# 3.9    332
# 2.8    315
# 4.1    274
# 4.0    266
# 2.7    250
# 4.2    221
# 2.6    191
# 4.3    174
# 4.4    143
# 2.5    110
# 4.5     95
# 2.4     87
# 4.6     78
# 4.9     61
# 2.3     47
# 4.7     41
# 2.2     27
# 4.8     25
# 2.1     15
# 2.0      7
# 1.9      2
# 1.8      1
# Name: Aggregate rating, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df_clean['Aggregate rating'],bins=10)
plt.xlabel('Aggregate rating')
plt.ylabel('Number of ratings')
plt.title('Aggregate rating vs. Number of ratings for  cleaned data ')
# Out:
# Text(0.5, 1.0, 'Aggregate rating vs. Number of ratings for  cleaned data ')

# %%
plt.boxplot(df_clean['Aggregate rating'])
plt.xlabel('Rating data frequency')
plt.ylabel('Aggregate rating')
# Out:
# Text(0, 0.5, 'Aggregate rating')

# %% [markdown]
# Above Boxplot Concludes that data is Normally Distributed.

# %% [markdown]
# # Task 2:  Descriptive Analysis
#
#  Calculate basic statistical measures (mean,
#  median, standard deviation, etc.) for numerical
#  columns.

# %%
df[["Average Cost for two","Price range","Aggregate rating","Votes"]].describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    130.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# Explore the distribution of categorical
#  variables like "Country Code," "City," and
#  "Cuisines."
#
#  Identify the top cuisines and cities with the
#  highest number of restaurants.

# %%
print("Top Countries 10 having number of Restaurants listed ")
top_countries = df['Country Code'].value_counts().head(10)
top_countries
# Out:
# Top Countries 10 having number of Restaurants listed
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# Name: Country Code, dtype: int64

# %%
import seaborn as sns

sns.countplot(x="Country Code",data = df,palette='rocket')
sns.color_palette("rocket")
plt.title('Distribution of Restaurants  in top 10 countries')
plt.xlabel('Country Codes')
plt.ylabel('Number of Restaurants')
# Out:
# Text(0, 0.5, 'Number of Restaurants')

# %% [markdown]
# Country code 1 denotes India , So from the above plot the highest number of restaurants are present in India

# %% [markdown]
# Top Cities

# %%
print("Top Cities  having number of Restaurants listed ")
top_cities = df['City'].value_counts()
top_cities
# Out:
# Top Cities  having number of Restaurants listed
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: City, Length: 140, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="City",data = df,order=df['City'].value_counts().head(20).index,palette='viridis')
sns.color_palette("viridis")
plt.title('Distribution of Restaurants in top 20 countries')
plt.xlabel('Cities')
plt.xticks(rotation=45)
plt.ylabel('Number of Restaurants')
# Out:
# Text(0, 0.5, 'Number of Restaurants')

# %% [markdown]
# The above plot finalizes that the highest number of resturants are in Delhi.

# %% [markdown]
# Top Cuisines

# %%
print("Top Cusinies in the Dataset ")
top_cuisines = df['Cuisines'].value_counts()
top_cuisines
# Out:
# Top Cusinies in the Dataset
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(x="Cuisines",data = df,order=df['Cuisines'].value_counts().head(30).index,palette="cubehelix")
sns.color_palette("cubehelix")
plt.title('Distribution of Top 30 Cuisines')
plt.xlabel('Cuisines')
plt.xticks(rotation=90)
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # Task 3

# %% [markdown]
# Geospatial Analysis Visualize the locations of restaurants on a map using latitude and longitude information.

# %%
# !pip install geopandas
# !pip install shapely
# Out:
# Requirement already satisfied: geopandas in c:\users\dawood md\anaconda3\lib\site-packages (0.14.4)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\dawood md\anaconda3\lib\site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in c:\users\dawood md\anaconda3\lib\site-packages (from geopandas) (1.24.4)
# Requirement already satisfied: packaging in c:\users\dawood md\anaconda3\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\dawood md\anaconda3\lib\site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\dawood md\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\dawood md\anaconda3\lib\site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\dawood md\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (23.2.0)
# Requirement already satisfied: certifi in c:\users\dawood md\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in c:\users\dawood md\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\dawood md\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\dawood md\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\dawood md\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dawood md\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dawood md\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: colorama in c:\users\dawood md\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Requirement already satisfied: shapely in c:\users\dawood md\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\dawood md\anaconda3\lib\site-packages (from shapely) (1.24.4)

# %%
#Importing the necessary Libraries
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import point

# %%
geo_df = gpd.GeoDataFrame(df,geometry=gpd.points_from_xy(df.Longitude,df.Latitude))
world_map = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
geo_df.plot(ax=world_map.plot("continent" ,legend =True,figsize =(30,15)),marker ="*" ,color = 'blue')
plt.show()
# Out:
# C:\Users\Dawood MD\AppData\Local\Temp\ipykernel_28704\2227812995.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world_map = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# %% [markdown]
# Analyze the distribution of restaurants across different cities or countries.
# Determine if there is any correlation between the restaurant's location and its rating

# %%
plt.figure(figsize=(20,10))
sns.countplot(y="City",data = df,order=df['City'].value_counts().head(20).index,palette='viridis')
sns.color_palette("viridis")
plt.title('Distribution of Restaurants in top 20 countries')
plt.xlabel('Cities')
plt.ylabel('Number of Restaurants')
# Out:
# Text(0, 0.5, 'Number of Restaurants')

# %%
plt.figure(figsize=(8,4))
corr = df[["Longitude","Latitude","Aggregate rating"]].corr()
sns.heatmap(corr, cmap="coolwarm",fmt='.2f',annot=True)
plt.title('Correlation between Restuarants location and Aggregate rating')
plt.show()

# %% [markdown]
# # Level 2

# %% [markdown]
# Task 1 :
# Table Booking and Online Delivery Determine the percentage of restaurants that offer table booking and online delivery.

# %%
# Percentage of restaurants offers table bookings are as follows
table_booking_percentage = (df["Has Table booking"].value_counts()/len(df))*100
print(table_booking_percentage)
print("The percentage of Restaurants that has the table booking:",table_booking_percentage['Yes'],"%")
# Out:
# No     87.864179
# Yes    12.135821
# Name: Has Table booking, dtype: float64
# The percentage of Restaurants that has the table booking: 12.135820582687067 %

# %%
table_booking_labels = ['Does not offer table Booking','Offers Table booking']
plt.pie(table_booking_percentage,explode=(0.1,0.1),labels=table_booking_labels,autopct='%1.1f%%',colors=['#ff9999','#66b3ff'],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba327536d0>,
#   <matplotlib.patches.Wedge at 0x2ba32776750>],
#  [Text(-1.1138367877258852, 0.44650600254473793, 'Does not offer table Booking'),
#   Text(1.1138368504332377, -0.44650584611734423, 'Offers Table booking')],
#  [Text(-0.6497381261734331, 0.26046183481776375, '87.9%'),
#   Text(0.6497381627527219, -0.26046174356845075, '12.1%')])

# %%
# Percentage of restaurants offers Online delivery are as follows
online_delivery_percentage = (df["Has Online delivery"].value_counts()/len(df))*100
print(online_delivery_percentage)
print("The percentage of Restaurants that has the Online delivery:",online_delivery_percentage['Yes'],"%")
# Out:
# No     74.313561
# Yes    25.686439
# Name: Has Online delivery, dtype: float64
# The percentage of Restaurants that has the Online delivery: 25.686438901697755 %

# %%
online_delivery_labels = ['Does not has Online Delivery','Has Online Delivery']
plt.pie(online_delivery_percentage,explode=(0.1,0.1),labels=online_delivery_labels,autopct='%1.1f%%',colors=['gray', 'saddlebrown'],shadow=True,)
# Out:
# ([<matplotlib.patches.Wedge at 0x2ba326e7ed0>,
#   <matplotlib.patches.Wedge at 0x2ba326e5610>],
#  [Text(-0.8300337062013308, 0.8666279747213813, 'Does not has Online Delivery'),
#   Text(0.8300337873408938, -0.8666278970080136, 'Has Online Delivery')],
#  [Text(-0.4841863286174429, 0.505532985254139, '74.3%'),
#   Text(0.48418637594885466, -0.5055329399213412, '25.7%')])

# %% [markdown]
# Compare the average ratings of restaurants with table booking and those without.

# %%
#Calculating the average rating of restaurants with table booking and those without
avg_rating_with_table_booking = df[df["Has Table booking"]=='Yes']["Aggregate rating"].mean()
avg_rating_without_table_booking = df[df["Has Table booking"]=='No']["Aggregate rating"].mean()

#Plotting Essentials
categories = ['With Table Booking','Without Table booking']
avg_ratings = [avg_rating_with_table_booking,avg_rating_without_table_booking]

#Plotting the Bar Graph
plt.bar(categories,avg_ratings,color =['#66b3ff','#ff9999',] )
plt.xlabel('Table Booking')
plt.ylabel("Average Rating")
plt.title('Plot Between Table booking Vs. Average Rating')
plt.show()

# %% [markdown]
# Analyze the availability of online delivery among restaurants with different price ranges.

# %%
#Categories the Data into price range and calculate the proportion of online delivery
price_ranges = df['Price range'].unique()
availability = []

for range in price_ranges:
    total_range = df[df["Price range"] == range].shape[0]
    online_delivery_range = df[(df['Price range'] == range) & (df['Has Online delivery'] == 'Yes')].shape[0]
    proportion = online_delivery_range / total_range if total_range > 0 else 0
    availability.append(proportion)
    
# Preparing the Data Essentials for Plotting
categories = price_ranges
proportions = availability

#Plotting the Bar Graph
plt.bar(categories,proportions,color =['#66b3ff','#ff9999',"#99ff99"] )
plt.xlabel('Price range')
plt.ylabel("Restaurants Ofeering Online Delivery")
plt.title('Plot Between Online Delivery Availability Vs. Price range')
plt.show()

# %% [markdown]
# Task 2 : Price Range Analysis
# Determine the most common price range among all the restaurants.

# %%
#counting the occurence of each price range
price_range_counts = df["Price range"].value_counts()

# Determining the most common price range among all the restaurants
most_common_price_range = price_range_counts.idxmax()
most_common_count = price_range_counts.max()

#Visualization of the distribution of the price range
price_range_counts.plot(kind ="bar",color ="indigo")
plt.xlabel('Price range')
plt.ylabel("Number of Restuarnts")
plt.title('Distribution of Price range of the Restaurants')
plt.show()

print(f'The Most Common price of the restuarnts is:{most_common_price_range} with {most_common_count} Restaurants')
# Out:
# The Most Common price of the restuarnts is:1 with 4438 Restaurants

# %% [markdown]
# Calculate the average rating for each price range.Identify the color that represents the highest average rating among different price ranges.

# %%
#calculate the average ratings for each price range
average_ratings = df.groupby("Price range")["Aggregate rating"].mean().reset_index()

print(average_ratings)

# visualize the average ratings with the colors
plt.bar(average_ratings["Price range"],average_ratings["Aggregate rating"],color =['blue','red','yellow','green'])
plt.xlabel('Price range')
plt.ylabel("Aggregate rating")
plt.title('Average rating Vs. Price range')
plt.xticks(rotation = 45)
plt.show()
# Out:
#    Price range  Aggregate rating
# 0            1          1.997476
# 1            2          2.941054
# 2            3          3.682633
# 3            4          3.817918

# %% [markdown]
# Task 3: Feature Engineering
# Extract additional features from the existing columns, such as the length of the restaurant name or address.

# %%
#Extracting the length of the restaurant names
df['Name length'] = df['Restaurant Name'].apply(len)

#Extracting the legth of the address 
df['Address length'] = df['Address'].apply(len)

df.head(25)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# 12        6318433                          Silantro Fil-Mex           162
# 13        6310470                                Guevarra's           162
# 14        6314605                   Sodam Korean Restaurant           162
# 15       18185059                             Cafe Arabelle           162
# 16       18182702                  Nonna's Pasta & Pizzeria           162
# 17        6318213                                Balay Dako           162
# 18       18255654                Hobing Korean Dessert Cafe           162
# 19        6308205                   Wildflour Cafe + Bakery           162
# 20        6315438                            NIU by Vikings           162
# 21        6310406             The Food Hall by Todd English           162
# 22        6600681                               Chez Michou            30
# 23        6601005                       Cafii Daniel Briand            30
# 24        6600292                  Casa do Biscoito Mineiro            30
#
#                 City                                            Address  \
# 0        Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1        Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2   Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3   Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4   Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
# 5   Mandaluyong City  Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 6         Pasay City  Building K, SM By The Bay, Sunset Boulevard, M...
# 7         Pasay City  Building B, By The Bay, Seaside Boulevard, Mal...
# 8         Pasay City  Plaza Level, Sofitel Philippine Plaza Manila, ...
# 9         Pasig City  Brixton Technology Center, 10 Brixton Street, ...
# 11    488             4.0          31             44
# 12    294             5.0          16             68
# 13    458             4.0          10             68
# 14    223             4.0          23             53
# 15     29             3.0          13             77
# 16     72             4.0          24             65
# 17    211             5.0          10             32
# 18    118             5.0          26            103
# 19    392             4.0          23             97
# 20    535             5.0          14             92
# 21    618             5.0          29             87
# 22      6             2.0          11             49
# 23      9             3.0          19             48
# 24     11             3.0          24             51
#
# [25 rows x 24 columns]

# %% [markdown]
# Create new features like "Has Table Booking" or "Has Online Delivery" by encoding categorical variables

# %%
# Creationg the new feature for table booking and online delivery
df['has table booking'] = df['Has Table booking'].apply(lambda x: 1 if x == 'Yes' else 0)
df['has online delivery'] = df['Has Online delivery'].apply(lambda x: 1 if x == 'Yes' else 0)

df.head(25)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# 12        6318433                          Silantro Fil-Mex           162
# 13        6310470                                Guevarra's           162
# 14        6314605                   Sodam Korean Restaurant           162
# 15       18185059                             Cafe Arabelle           162
# 16       18182702                  Nonna's Pasta & Pizzeria           162
# 17        6318213                                Balay Dako           162
# 18       18255654                Hobing Korean Dessert Cafe           162
# 19        6308205                   Wildflour Cafe + Bakery           162
# 20        6315438                            NIU by Vikings           162
# 21        6310406             The Food Hall by Todd English           162
# 22        6600681                               Chez Michou            30
# 23        6601005                       Cafii Daniel Briand            30
# 24        6600292                  Casa do Biscoito Mineiro            30
#
#                 City                                            Address  \
# 0        Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# 1        Makati City  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2   Mandaluyong City  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3   Mandaluyong City  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4   Mandaluyong City  Third Floor, Mega Atrium, SM Megamall, Ortigas...
# 5   Mandaluyong City  Ground Floor, Mega Fashion Hall, SM Megamall, ...
# 6         Pasay City  Building K, SM By The Bay, Sunset Boulevard, M...
# 7         Pasay City  Building B, By The Bay, Seaside Boulevard, Mal...
# 8         Pasay City  Plaza Level, Sofitel Philippine Plaza Manila, ...
# 9         Pasig City  Brixton Technology Center, 10 Brixton Street, ...
# 10        Pasig City       75 East Capitol Drive, Kapitolyo, Pasig City
# 11        Pasig City       23 East Capitol Drive, Kapitolyo, Pasig City
# 12       Quezon City  Second Floor, UP Town Center, Katipunan Avenue...
# 13     San Juan City  387 P. Guevarra Corner Argonne Street, Additio...
# 14     San Juan City  17 J. Abad Santos Drive, Little Baguio, San Ju...
# 15        Santa Rosa  Ayala Mall, Solenad, Nuvali, Santa Rosa - Taga...
# 16        Santa Rosa  Ground Floor, Building G, Solenad 3, Nuvali, D...
# 17     Tagaytay City                   Aguinaldo Highway, Tagaytay City
# 2             Seafood, Asian, Filipino, Indian  ...            4
# 3                              Japanese, Sushi  ...            4
# 4                             Japanese, Korean  ...            4
# 5                                      Chinese  ...            3
# 6                              Asian, European  ...            4
# 7           Seafood, Filipino, Asian, European  ...            4
# 8                      European, Asian, Indian  ...            4
# 9                                     Filipino  ...            3
# 10                           Filipino, Mexican  ...            3
# 11               American, Ice Cream, Desserts  ...            3
# 12                           Filipino, Mexican  ...            3
# 13                                    Filipino  ...            3
# 14                                      Korean  ...            3
# 15           Cafe, American, Italian, Filipino  ...            3
# 16                              Italian, Pizza  ...            3
# 17                                    Filipino  ...            3
# 18                      Cafe, Korean, Desserts  ...            2
# 19             Cafe, Bakery, American, Italian  ...            4
# 20  Seafood, American, Mediterranean, Japanese  ...            4
# 21           American, Asian, Italian, Seafood  ...            4
# 22                           Fast Food, French  ...            2
# 23                                        Cafe  ...            1
# 24                                      Bakery  ...            2
#
#    Aggregate rating Rating color Rating text Votes Numeric rating  \
# 0               4.8   Dark Green   Excellent   314            5.0
# 1               4.5   Dark Green   Excellent   591            5.0
# 2               4.4        Green   Very Good   270            4.0
# 3               4.9   Dark Green   Excellent   365            5.0
# 4               4.8   Dark Green   Excellent   229            5.0
# 5               4.4        Green   Very Good   336            4.0
# 6               4.0        Green   Very Good   520            4.0
# 7               4.2        Green   Very Good   677            4.0
# 8               4.9   Dark Green   Excellent   621            5.0
# 9               4.8   Dark Green   Excellent   532            5.0
# 10              4.9   Dark Green   Excellent  1070            5.0
# 11              4.2        Green   Very Good   488            4.0
# 12              4.8   Dark Green   Excellent   294            5.0
# 13              4.2        Green   Very Good   458            4.0
# 14              4.3        Green   Very Good   223            4.0
# 15              3.6       Yellow        Good    29            3.0
# 16              4.0        Green   Very Good    72            4.0
# 17              4.5   Dark Green   Excellent   211            5.0
# 18              4.5   Dark Green   Excellent   118            5.0
# 19              4.4        Green   Very Good   392            4.0
# 20              4.7   Dark Green   Excellent   535            5.0
# 21              4.5   Dark Green   Excellent   618            5.0
# 22              3.0       Orange     Average     6            2.0
# 23              3.8       Yellow        Good     9            3.0
# 24              3.7       Yellow        Good    11            3.0
#
#     Name length  Address length has table booking has online delivery
# 0            16              71                 1                   0
# 1            16              67                 1                   0
# 2            22              56                 1                   0
# 3             4              70                 0                   0
# 4            11              64                 1                   0
# 5            12              71                 0                   0
# 6            10              83                 1                   0
# 7             7              81                 1                   0
# 8            40              69                 1                   0
# 9             8              67                 1                   0
# 10           16              44                 0                   0
# 11           31              44                 1                   0
# 12           16              68                 0                   0
# 13           10              68                 1                   0
# 14           23              53                 0                   0
# 15           13              77                 0                   0
# 16           24              65                 0                   0
# 17           10              32                 1                   0
# 18           26             103                 0                   0
# 19           23              97                 1                   0
# 20           14              92                 1                   0
# 21           29              87                 1                   0
# 22           11              49                 0                   0
# 23           19              48                 0                   0
# 24           24              51                 0                   0
#
# [25 rows x 26 columns]

# %%
#save the Updated Dataframe into the New csv file
df.to_csv(r"C:\Users\Dawood MD\OneDrive\Desktop\Cognifyz\updated_resturant_Dataset.csv")

# %% [markdown]
# # Thank you
